# %%
import math

def dec2binary(a, k):
    binary = bin(a)[2:]
    padded_binary = '0'*(k-len(binary)) + binary  
    return padded_binary

def arithmetic_decode(code, n):
    len_txt = int(code[0:32], 2)
    len_alpha = int(code[32:48], 2)
    alpha_bin = code[48:48+len_alpha*7]
    C = code[48+len_alpha*7:]
    alpha = []
    for i in range (0, len_alpha*7, 7):
        bin = alpha_bin[i:i+7]
        lletra = chr(int(bin, 2))
        alpha.append(lletra)
    
    it_alpha = 1
    src = {'\x1b':1}
    total = 1

    txt = ''
    lletra = ''
    k = 8
    a = 0
    b = 2**k-1
    count = k-1
    end = False
    y = int(C[0:k], 2)

    print("Alpha, gamma i beta inicials:", a, y, b)

    while len(txt) != len_txt:
        p = 0
        aux_p = 0
        d = b-a+1
        for clave in src.keys():
            aux_p = p
            p += src[clave]
            if a+math.floor(d * p/total) > y:
                print(clave)
                print(aux_p, p)
                print(src)
                lletra = clave
                break
        print("Determinen nova lletra:", lletra)
        if lletra == '\x1b':
            lletra = alpha[it_alpha]
            it_alpha += 1
            print("Determinen la verdadera nova lletra:", lletra)
            src.update({lletra:0})
        txt += lletra
        src[lletra] = src[lletra]+1
        b = a + math.floor(d * p/total)-1
        a = a + math.floor(d * aux_p/total) 
        total += 1
        print("Nous alpha, gamma i beta:", a, y, b)
        a_bin = dec2binary(a, k)
        y_bin = dec2binary(y, k)
        b_bin = dec2binary(b, k)
        print("En binari:", a_bin, y_bin, b_bin)

        while (a_bin[0] == b_bin[0]):
            if count < len(C)-1:
                count += 1
            else:
                end = True
            char = a_bin[0]
            a = a*2
            b = b*2 +1
            if C[count] == '0' or end:
                y = y*2
            else:
                y = y*2+1
            if (char == '1'):
                a = a - 2**k
                b = b - 2**k
                y = y - 2**k
            a_bin = dec2binary(a, k)
            y_bin = dec2binary(y, k)
            b_bin = dec2binary(b, k)
            print ("Reescalat:", a_bin, y_bin, b_bin)
            
        if a_bin[1] == '1' and b_bin[1] == '0':
            while(not(a_bin[0:2] == '00' or b_bin[0:2] == '11')):
                if count < len(C)-1:
                    count += 1
                else:
                    end = True
                a = a*2-2**(k-1)
                b = b*2-2**(k-1)+1
                if C[count] == '0' or end:
                    y = y*2-2**(k-1)
                else:
                    y = y*2-2**(k-1)+1
                a_bin = dec2binary(a, k)
                y_bin = dec2binary(y, k)
                b_bin = dec2binary(b, k)
                print ("Underflow:", a_bin, y_bin, b_bin)
        
        print("Queden alpha, gamma i beta:", a, y, b)
        print()
    return txt

# %%
C = ''
arithmetic_decode(C, 1)
# Out:
# Alpha, gamma i beta inicials: 0 4 255
#
# 0 1.0
# {'\x1b': 1}
# Determinen nova lletra:
# Determinen la verdadera nova lletra: S
# Nous alpha, gamma i beta: 0 4 255
# En binari: 00000000 00000100 11111111
# Queden alpha, gamma i beta: 0 4 255
#
#
# 0 0.5
# {'\x1b': 1, 'S': 1}
# Determinen nova lletra:
# Determinen la verdadera nova lletra: e
# Nous alpha, gamma i beta: 0 4 127
# En binari: 00000000 00000100 01111111
# Reescalat: 00000000 00001000 11111111
# Queden alpha, gamma i beta: 0 8 255
#
#
# 0 0.3333333333333333
# {'\x1b': 1, 'S': 1, 'e': 1}
# Determinen nova lletra:
# Determinen la verdadera nova lletra: t
# Nous alpha, gamma i beta: 0 8 84
# En binari: 00000000 00001000 01010100
# Reescalat: 00000000 00010000 10101001
# Queden alpha, gamma i beta: 0 16 169
#
#
# 0 0.25
# {'\x1b': 1, 'S': 1, 'e': 1, 't': 1}
# Determinen nova lletra:
# Determinen la verdadera nova lletra: z
# Nous alpha, gamma i beta: 0 16 41
# En binari: 00000000 00010000 00101001
# Reescalat: 00000000 00100001 01010011
# Reescalat: 00000000 01000011 10100111
# Queden alpha, gamma i beta: 0 67 167
#
# e
# 0.4 0.6000000000000001
# {'\x1b': 1, 'S': 1, 'e': 1, 't': 1, 'z': 1}
# Determinen nova lletra: e
# Nous alpha, gamma i beta: 67 67 99
# En binari: 01000011 01000011 01100011
# Reescalat: 10000110 10000110 11000111
# Reescalat: 00001100 00001100 10001111
# Queden alpha, gamma i beta: 12 12 143
#
#
# 0 0.16666666666666666
# {'\x1b': 1, 'S': 1, 'e': 2, 't': 1, 'z': 1}
# Determinen nova lletra:
# Determinen la verdadera nova lletra:
# Nous alpha, gamma i beta: 12 12 33
# En binari: 00001100 00001100 00100001
# Reescalat: 00011000 00011000 01000011
# Reescalat: 00110000 00110000 10000111
# Queden alpha, gamma i beta: 48 48 135
#
#
# 0 0.14285714285714285
# {'\x1b': 1, 'S': 1, 'e': 2, 't': 1, 'z': 1, ' ': 1}
# Determinen nova lletra:
# Determinen la verdadera nova lletra: j
# Nous alpha, gamma i beta: 48 48 59
# En binari: 00110000 00110000 00111011
# Reescalat: 01100000 01100001 01110111
# Reescalat: 11000000 11000010 11101111
# Reescalat: 10000000 10000101 11011111
# Reescalat: 00000000 00001010 10111111
# Queden alpha, gamma i beta: 0 10 191
#
#
# 0 0.125
# {'\x1b': 1, 'S': 1, 'e': 2, 't': 1, 'z': 1, ' ': 1, 'j': 1}
# Determinen nova lletra:
# Determinen la verdadera nova lletra: u
# Nous alpha, gamma i beta: 0 10 23
# En binari: 00000000 00001010 00010111
# Reescalat: 00000000 00010101 00101111
# Reescalat: 00000000 00101010 01011111
# Reescalat: 00000000 01010101 10111111
# Queden alpha, gamma i beta: 0 85 191
#
# t
# 0.4444444444444444 0.5555555555555556
# {'\x1b': 1, 'S': 1, 'e': 2, 't': 1, 'z': 1, ' ': 1, 'j': 1, 'u': 1}
# Determinen nova lletra: t
# Nous alpha, gamma i beta: 85 85 105
# En binari: 01010101 01010101 01101001
# Reescalat: 10101010 10101010 11010011
# Reescalat: 01010100 01010101 10100111
# Underflow: 00101000 00101011 11001111
# Queden alpha, gamma i beta: 40 43 207
#
#
# 0 0.1
# {'\x1b': 1, 'S': 1, 'e': 2, 't': 2, 'z': 1, ' ': 1, 'j': 1, 'u': 1}
# Determinen nova lletra:
# Determinen la verdadera nova lletra: g
# Nous alpha, gamma i beta: 40 43 55
# En binari: 00101000 00101011 00110111
# Reescalat: 01010000 01010110 01101111
# Reescalat: 10100000 10101100 11011111
# Reescalat: 01000000 01011000 10111111
# Underflow: 00000000 00110000 11111111
# Queden alpha, gamma i beta: 0 48 255
#
# e
# 0.18181818181818182 0.36363636363636365
# {'\x1b': 1, 'S': 1, 'e': 2, 't': 2, 'z': 1, ' ': 1, 'j': 1, 'u': 1, 'g': 1}
# Determinen nova lletra: e
# Nous alpha, gamma i beta: 46 48 92
# En binari: 00101110 00110000 01011100
# Reescalat: 01011100 01100000 10111001
# Underflow: 00111000 01000001 11110011
# Queden alpha, gamma i beta: 56 65 243
#
#
# 0 0.08333333333333333
# {'\x1b': 1, 'S': 1, 'e': 3, 't': 2, 'z': 1, ' ': 1, 'j': 1, 'u': 1, 'g': 1}
# Determinen nova lletra:
# Determinen la verdadera nova lletra: s
# Nous alpha, gamma i beta: 56 65 70
# En binari: 00111000 01000001 01000110
# Reescalat: 01110000 10000010 10001101
# Underflow: 01100000 10000100 10011011
# Underflow: 01000000 10001001 10110111
# Underflow: 00000000 10010011 11101111
# Queden alpha, gamma i beta: 0 147 239
#
#
# 0.6153846153846154 0.6923076923076923
# {'\x1b': 1, 'S': 1, 'e': 3, 't': 2, 'z': 1, ' ': 1, 'j': 1, 'u': 1, 'g': 1, 's': 1}
# Determinen nova lletra:
# Nous alpha, gamma i beta: 147 147 165
# En binari: 10010011 10010011 10100101
# Reescalat: 00100110 00100110 01001011
# Reescalat: 01001100 01001100 10010111
# Underflow: 00011000 00011000 10101111
# Queden alpha, gamma i beta: 24 24 175
#
#
# 0 0.07142857142857142
# {'\x1b': 1, 'S': 1, 'e': 3, 't': 2, 'z': 1, ' ': 2, 'j': 1, 'u': 1, 'g': 1, 's': 1}
# Determinen nova lletra:
# Determinen la verdadera nova lletra: d
# Nous alpha, gamma i beta: 24 24 33
# En binari: 00011000 00011000 00100001
# Reescalat: 00110000 00110000 01000011
# Reescalat: 01100000 01100001 10000111
# Underflow: 01000000 01000011 10001111
# Underflow: 00000000 00000110 10011111
# Queden alpha, gamma i beta: 0 6 159
#
#
# 0 0.06666666666666667
# {'\x1b': 1, 'S': 1, 'e': 3, 't': 2, 'z': 1, ' ': 2, 'j': 1, 'u': 1, 'g': 1, 's': 1, 'd': 1}
# Determinen nova lletra:
# Determinen la verdadera nova lletra: '
# Nous alpha, gamma i beta: 0 6 9
# En binari: 00000000 00000110 00001001
# Reescalat: 00000000 00001101 00010011
# Reescalat: 00000000 00011011 00100111
# Reescalat: 00000000 00110111 01001111
# Reescalat: 00000000 01101110 10011111
# Queden alpha, gamma i beta: 0 110 159
#
# u
# 0.6875 0.75
# {'\x1b': 1, 'S': 1, 'e': 3, 't': 2, 'z': 1, ' ': 2, 'j': 1, 'u': 1, 'g': 1, 's': 1, 'd': 1, "'": 1}
# Determinen nova lletra: u
# Nous alpha, gamma i beta: 110 110 119
# En binari: 01101110 01101110 01110111
# Reescalat: 11011100 11011100 11101111
# Reescalat: 10111000 10111001 11011111
# Reescalat: 01110000 01110010 10111111
# Underflow: 01100000 01100100 11111111
# Queden alpha, gamma i beta: 96 100 255
#
#
# 0 0.058823529411764705
# {'\x1b': 1, 'S': 1, 'e': 3, 't': 2, 'z': 1, ' ': 2, 'j': 1, 'u': 2, 'g': 1, 's': 1, 'd': 1, "'": 1}
# Determinen nova lletra:
# Determinen la verdadera nova lletra: n
# Nous alpha, gamma i beta: 96 100 104
# En binari: 01100000 01100100 01101000
# Reescalat: 11000000 11001001 11010001
# Reescalat: 10000000 10010010 10100011
# Reescalat: 00000000 00100100 01000111
# Reescalat: 00000000 01001001 10001111
# Queden alpha, gamma i beta: 0 73 143
#
#
# 0.4444444444444444 0.5555555555555556
# {'\x1b': 1, 'S': 1, 'e': 3, 't': 2, 'z': 1, ' ': 2, 'j': 1, 'u': 2, 'g': 1, 's': 1, 'd': 1, "'": 1, 'n': 1}
# Determinen nova lletra:
# Nous alpha, gamma i beta: 64 73 79
# En binari: 01000000 01001001 01001111
# Reescalat: 10000000 10010011 10011111
# Reescalat: 00000000 00100111 00111111
# Reescalat: 00000000 01001110 01111111
# Reescalat: 00000000 10011100 11111111
# Queden alpha, gamma i beta: 0 156 255
#
# j
# 0.5789473684210527 0.631578947368421
# {'\x1b': 1, 'S': 1, 'e': 3, 't': 2, 'z': 1, ' ': 3, 'j': 1, 'u': 2, 'g': 1, 's': 1, 'd': 1, "'": 1, 'n': 1}
# Determinen nova lletra: j
# Nous alpha, gamma i beta: 148 156 160
# En binari: 10010100 10011100 10100000
# Reescalat: 00101000 00111001 01000001
# Reescalat: 01010000 01110011 10000011
# Underflow: 00100000 01100110 10000111
# Queden alpha, gamma i beta: 32 102 135
#
# u
# 0.6499999999999999 0.7499999999999999
# {'\x1b': 1, 'S': 1, 'e': 3, 't': 2, 'z': 1, ' ': 3, 'j': 2, 'u': 2, 'g': 1, 's': 1, 'd': 1, "'": 1, 'n': 1}
# Determinen nova lletra: u
# Nous alpha, gamma i beta: 99 102 108
# En binari: 01100011 01100110 01101100
# Reescalat: 11000110 11001100 11011001
# Reescalat: 10001100 10011000 10110011
# Reescalat: 00011000 00110001 01100111
# Reescalat: 00110000 01100010 11001111
# Queden alpha, gamma i beta: 48 98 207
#
# t
# 0.23809523809523808 0.3333333333333333
# {'\x1b': 1, 'S': 1, 'e': 3, 't': 2, 'z': 1, ' ': 3, 'j': 2, 'u': 3, 'g': 1, 's': 1, 'd': 1, "'": 1, 'n': 1}
# Determinen nova lletra: t
# Nous alpha, gamma i beta: 86 98 100
# En binari: 01010110 01100010 01100100
# Reescalat: 10101100 11000100 11001001
# Reescalat: 01011000 10001001 10010011
# Underflow: 00110000 10010010 10100111
# Queden alpha, gamma i beta: 48 146 167
#
# s
# 0.8181818181818181 0.8636363636363635
# {'\x1b': 1, 'S': 1, 'e': 3, 't': 3, 'z': 1, ' ': 3, 'j': 2, 'u': 3, 'g': 1, 's': 1, 'd': 1, "'": 1, 'n': 1}
# Determinen nova lletra: s
# Nous alpha, gamma i beta: 146 146 150
# En binari: 10010010 10010010 10010110
# Reescalat: 00100100 00100100 00101101
# Reescalat: 01001000 01001000 01011011
# Reescalat: 10010000 10010001 10110111
# Reescalat: 00100000 00100010 01101111
# Reescalat: 01000000 01000100 11011111
# Queden alpha, gamma i beta: 64 68 223
#
#
# 0 0.043478260869565216
# {'\x1b': 1, 'S': 1, 'e': 3, 't': 3, 'z': 1, ' ': 3, 'j': 2, 'u': 3, 'g': 1, 's': 2, 'd': 1, "'": 1, 'n': 1}
# Determinen nova lletra:
# Determinen la verdadera nova lletra: a
# Nous alpha, gamma i beta: 64 68 69
# En binari: 01000000 01000100 01000101
# Reescalat: 10000000 10001000 10001011
# Reescalat: 00000000 00010000 00010111
# Reescalat: 00000000 00100000 00101111
# Reescalat: 00000000 01000001 01011111
# Reescalat: 00000000 10000011 10111111
# Queden alpha, gamma i beta: 0 131 191
#
# u
# 0.5833333333333334 0.7083333333333334
# {'\x1b': 1, 'S': 1, 'e': 3, 't': 3, 'z': 1, ' ': 3, 'j': 2, 'u': 3, 'g': 1, 's': 2, 'd': 1, "'": 1, 'n': 1, 'a': 1}
# Determinen nova lletra: u
# Nous alpha, gamma i beta: 112 131 135
# En binari: 01110000 10000011 10000111
# Underflow: 01100000 10000111 10001111
# Underflow: 01000000 10001110 10011111
# Underflow: 00000000 10011100 10111111
# Queden alpha, gamma i beta: 0 156 191
#
# s
# 0.76 0.84
# {'\x1b': 1, 'S': 1, 'e': 3, 't': 3, 'z': 1, ' ': 3, 'j': 2, 'u': 4, 'g': 1, 's': 2, 'd': 1, "'": 1, 'n': 1, 'a': 1}
# Determinen nova lletra: s
# Nous alpha, gamma i beta: 145 156 160
# En binari: 10010001 10011100 10100000
# Reescalat: 00100010 00111000 01000001
# Reescalat: 01000100 01110001 10000011
# Underflow: 00001000 01100010 10000111
# Queden alpha, gamma i beta: 8 98 135
#
# g
# 0.6923076923076924 0.7307692307692308
# {'\x1b': 1, 'S': 1, 'e': 3, 't': 3, 'z': 1, ' ': 3, 'j': 2, 'u': 4, 'g': 1, 's': 3, 'd': 1, "'": 1, 'n': 1, 'a': 1}
# Determinen nova lletra: g
# Nous alpha, gamma i beta: 96 98 100
# En binari: 01100000 01100010 01100100
# Reescalat: 11000000 11000101 11001001
# Reescalat: 10000000 10001011 10010011
# Reescalat: 00000000 00010110 00100111
# Reescalat: 00000000 00101100 01001111
# Reescalat: 00000000 01011001 10011111
# Queden alpha, gamma i beta: 0 89 159
#
# u
# 0.5185185185185185 0.6666666666666666
# {'\x1b': 1, 'S': 1, 'e': 3, 't': 3, 'z': 1, ' ': 3, 'j': 2, 'u': 4, 'g': 2, 's': 3, 'd': 1, "'": 1, 'n': 1, 'a': 1}
# Determinen nova lletra: u
# Nous alpha, gamma i beta: 82 89 105
# En binari: 01010010 01011001 01101001
# Reescalat: 10100100 10110010 11010011
# Reescalat: 01001000 01100100 10100111
# Underflow: 00010000 01001001 11001111
# Queden alpha, gamma i beta: 16 73 207
#
# z
# 0.2857142857142857 0.3214285714285714
# {'\x1b': 1, 'S': 1, 'e': 3, 't': 3, 'z': 1, ' ': 3, 'j': 2, 'u': 5, 'g': 2, 's': 3, 'd': 1, "'": 1, 'n': 1, 'a': 1}
# Determinen nova lletra: z
# Nous alpha, gamma i beta: 70 73 76
# En binari: 01000110 01001001 01001100
# Reescalat: 10001100 10010011 10011001
# Reescalat: 00011000 00100110 00110011
# Reescalat: 00110000 01001100 01100111
# Reescalat: 01100000 10011001 11001111
# Queden alpha, gamma i beta: 96 153 207
#
# u
# 0.5172413793103449 0.6896551724137931
# {'\x1b': 1, 'S': 1, 'e': 3, 't': 3, 'z': 2, ' ': 3, 'j': 2, 'u': 5, 'g': 2, 's': 3, 'd': 1, "'": 1, 'n': 1, 'a': 1}
# Determinen nova lletra: u
# Nous alpha, gamma i beta: 153 153 172
# En binari: 10011001 10011001 10101100
# Reescalat: 00110010 00110011 01011001
# Reescalat: 01100100 01100111 10110011
# Underflow: 01001000 01001110 11100111
# Queden alpha, gamma i beta: 72 78 231
#
# S
# 0.03333333333333333 0.06666666666666667
# {'\x1b': 1, 'S': 1, 'e': 3, 't': 3, 'z': 2, ' ': 3, 'j': 2, 'u': 6, 'g': 2, 's': 3, 'd': 1, "'": 1, 'n': 1, 'a': 1}
# Determinen nova lletra: S
# Nous alpha, gamma i beta: 77 78 81
# En binari: 01001101 01001110 01010001
# Reescalat: 10011010 10011101 10100011
# Reescalat: 00110100 00111011 01000111
# Reescalat: 01101000 01110110 10001111
# Underflow: 01010000 01101101 10011111
# Underflow: 00100000 01011010 10111111
# Queden alpha, gamma i beta: 32 90 191
#
#
# 0.3548387096774193 0.4516129032258064
# {'\x1b': 1, 'S': 2, 'e': 3, 't': 3, 'z': 2, ' ': 3, 'j': 2, 'u': 6, 'g': 2, 's': 3, 'd': 1, "'": 1, 'n': 1, 'a': 1}
# Determinen nova lletra:
# Nous alpha, gamma i beta: 88 90 103
# En binari: 01011000 01011010 01100111
# Reescalat: 10110000 10110100 11001111
# Reescalat: 01100000 01101001 10011111
# Underflow: 01000000 01010010 10111111
# Underflow: 00000000 00100100 11111111
# Queden alpha, gamma i beta: 0 36 255
#
# e
# 0.09375 0.1875
# {'\x1b': 1, 'S': 2, 'e': 3, 't': 3, 'z': 2, ' ': 4, 'j': 2, 'u': 6, 'g': 2, 's': 3, 'd': 1, "'": 1, 'n': 1, 'a': 1}
# Determinen nova lletra: e
# Nous alpha, gamma i beta: 24 36 47
# En binari: 00011000 00100100 00101111
# Reescalat: 00110000 01001000 01011111
# Reescalat: 01100000 10010000 10111111
# Underflow: 01000000 10100000 11111111
# Queden alpha, gamma i beta: 64 160 255
#
# j
# 0.48484848484848486 0.5454545454545454
# {'\x1b': 1, 'S': 2, 'e': 4, 't': 3, 'z': 2, ' ': 4, 'j': 2, 'u': 6, 'g': 2, 's': 3, 'd': 1, "'": 1, 'n': 1, 'a': 1}
# Determinen nova lletra: j
# Nous alpha, gamma i beta: 157 160 167
# En binari: 10011101 10100000 10100111
# Reescalat: 00111010 01000001 01001111
# Reescalat: 01110100 10000011 10011111
# Underflow: 01101000 10000111 10111111
# Underflow: 01010000 10001111 11111111
# Queden alpha, gamma i beta: 80 143 255
#
#
# 0.35294117647058826 0.47058823529411764
# {'\x1b': 1, 'S': 2, 'e': 4, 't': 3, 'z': 2, ' ': 4, 'j': 3, 'u': 6, 'g': 2, 's': 3, 'd': 1, "'": 1, 'n': 1, 'a': 1}
# Determinen nova lletra:
# Nous alpha, gamma i beta: 142 143 161
# En binari: 10001110 10001111 10100001
# Reescalat: 00011100 00011111 01000011
# Reescalat: 00111000 00111110 10000111
# Queden alpha, gamma i beta: 56 62 135
#
# e
# 0.08571428571428572 0.2
# {'\x1b': 1, 'S': 2, 'e': 4, 't': 3, 'z': 2, ' ': 5, 'j': 3, 'u': 6, 'g': 2, 's': 3, 'd': 1, "'": 1, 'n': 1, 'a': 1}
# Determinen nova lletra: e
# Nous alpha, gamma i beta: 62 62 71
# En binari: 00111110 00111110 01000111
# Reescalat: 01111100 01111101 10001111
# Underflow: 01111000 01111010 10011111
# Underflow: 01110000 01110100 10111111
# Underflow: 01100000 01101001 11111111
# Queden alpha, gamma i beta: 96 105 255
#
# S
# 0.027777777777777776 0.08333333333333333
# {'\x1b': 1, 'S': 2, 'e': 5, 't': 3, 'z': 2, ' ': 5, 'j': 3, 'u': 6, 'g': 2, 's': 3, 'd': 1, "'": 1, 'n': 1, 'a': 1}
# Determinen nova lletra: S
# Nous alpha, gamma i beta: 100 105 108
# En binari: 01100100 01101001 01101100
# Reescalat: 11001000 11010011 11011001
# Reescalat: 10010000 10100111 10110011
# Reescalat: 00100000 01001110 01100111
# Reescalat: 01000000 10011101 11001111
# Queden alpha, gamma i beta: 64 157 207
#
# u
# 0.5945945945945947 0.7567567567567569
# {'\x1b': 1, 'S': 3, 'e': 5, 't': 3, 'z': 2, ' ': 5, 'j': 3, 'u': 6, 'g': 2, 's': 3, 'd': 1, "'": 1, 'n': 1, 'a': 1}
# Determinen nova lletra: u
# Nous alpha, gamma i beta: 149 157 171
# En binari: 10010101 10011101 10101011
# Reescalat: 00101010 00111011 01010111
# Reescalat: 01010100 01110111 10101111
# Underflow: 00101000 01101110 11011111
# Queden alpha, gamma i beta: 40 110 223
#
#
# 0.3684210526315789 0.5
# {'\x1b': 1, 'S': 3, 'e': 5, 't': 3, 'z': 2, ' ': 5, 'j': 3, 'u': 7, 'g': 2, 's': 3, 'd': 1, "'": 1, 'n': 1, 'a': 1}
# Determinen nova lletra:
# Nous alpha, gamma i beta: 107 110 131
# En binari: 01101011 01101110 10000011
# Underflow: 01010110 01011101 10000111
# Underflow: 00101100 00111011 10001111
# Queden alpha, gamma i beta: 44 59 143
#
# e
# 0.10256410256410256 0.23076923076923075
# {'\x1b': 1, 'S': 3, 'e': 5, 't': 3, 'z': 2, ' ': 6, 'j': 3, 'u': 7, 'g': 2, 's': 3, 'd': 1, "'": 1, 'n': 1, 'a': 1}
# Determinen nova lletra: e
# Nous alpha, gamma i beta: 54 59 66
# En binari: 00110110 00111011 01000010
# Reescalat: 01101100 01110110 10000101
# Underflow: 01011000 01101101 10001011
# Underflow: 00110000 01011010 10010111
# Queden alpha, gamma i beta: 48 90 151
#
#
# 0.375 0.525
# {'\x1b': 1, 'S': 3, 'e': 6, 't': 3, 'z': 2, ' ': 6, 'j': 3, 'u': 7, 'g': 2, 's': 3, 'd': 1, "'": 1, 'n': 1, 'a': 1}
# Determinen nova lletra:
# Nous alpha, gamma i beta: 87 90 101
# En binari: 01010111 01011010 01100101
# Reescalat: 10101110 10110101 11001011
# Reescalat: 01011100 01101011 10010111
# Underflow: 00111000 01010111 10101111
# Queden alpha, gamma i beta: 56 87 175
#
# t
# 0.24390243902439024 0.3170731707317073
# {'\x1b': 1, 'S': 3, 'e': 6, 't': 3, 'z': 2, ' ': 7, 'j': 3, 'u': 7, 'g': 2, 's': 3, 'd': 1, "'": 1, 'n': 1, 'a': 1}
# Determinen nova lletra: t
# Nous alpha, gamma i beta: 85 87 93
# En binari: 01010101 01010111 01011101
# Reescalat: 10101010 10101110 10111011
# Reescalat: 01010100 01011100 01110111
# Reescalat: 10101000 10111000 11101111
# Reescalat: 01010000 01110000 11011111
# Queden alpha, gamma i beta: 80 112 223
#
# e
# 0.09523809523809523 0.23809523809523808
# {'\x1b': 1, 'S': 3, 'e': 6, 't': 4, 'z': 2, ' ': 7, 'j': 3, 'u': 7, 'g': 2, 's': 3, 'd': 1, "'": 1, 'n': 1, 'a': 1}
# Determinen nova lletra: e
# Nous alpha, gamma i beta: 93 112 113
# En binari: 01011101 01110000 01110001
# Reescalat: 10111010 11100000 11100011
# Reescalat: 01110100 11000000 11000111
# Queden alpha, gamma i beta: 116 192 199
#
# d
# 0.9069767441860466 0.930232558139535
# {'\x1b': 1, 'S': 3, 'e': 7, 't': 4, 'z': 2, ' ': 7, 'j': 3, 'u': 7, 'g': 2, 's': 3, 'd': 1, "'": 1, 'n': 1, 'a': 1}
# Determinen nova lletra: d
# Nous alpha, gamma i beta: 192 192 193
# En binari: 11000000 11000000 11000001
# Reescalat: 10000000 10000001 10000011
# Reescalat: 00000000 00000010 00000111
# Reescalat: 00000000 00000101 00001111
# Reescalat: 00000000 00001011 00011111
# Reescalat: 00000000 00010110 00111111
# Reescalat: 00000000 00101100 01111111
# Reescalat: 00000000 01011001 11111111
# Queden alpha, gamma i beta: 0 89 255
#
# z
# 0.34090909090909094 0.3863636363636364
# {'\x1b': 1, 'S': 3, 'e': 7, 't': 4, 'z': 2, ' ': 7, 'j': 3, 'u': 7, 'g': 2, 's': 3, 'd': 2, "'": 1, 'n': 1, 'a': 1}
# Determinen nova lletra: z
# Nous alpha, gamma i beta: 87 89 97
# En binari: 01010111 01011001 01100001
# Reescalat: 10101110 10110010 11000011
# Reescalat: 01011100 01100100 10000111
# Underflow: 00111000 01001001 10001111
# Queden alpha, gamma i beta: 56 73 143
#
# e
# 0.08888888888888889 0.24444444444444446
# {'\x1b': 1, 'S': 3, 'e': 7, 't': 4, 'z': 3, ' ': 7, 'j': 3, 'u': 7, 'g': 2, 's': 3, 'd': 2, "'": 1, 'n': 1, 'a': 1}
# Determinen nova lletra: e
# Nous alpha, gamma i beta: 63 73 76
# En binari: 00111111 01001001 01001100
# Reescalat: 01111110 10010010 10011001
# Underflow: 01111100 10100100 10110011
# Underflow: 01111000 11001000 11100111
# Queden alpha, gamma i beta: 120 200 231
#
# u
# 0.6304347826086957 0.782608695652174
# {'\x1b': 1, 'S': 3, 'e': 8, 't': 4, 'z': 3, ' ': 7, 'j': 3, 'u': 7, 'g': 2, 's': 3, 'd': 2, "'": 1, 'n': 1, 'a': 1}
# Determinen nova lletra: u
# Nous alpha, gamma i beta: 190 200 206
# En binari: 10111110 11001000 11001110
# Reescalat: 01111100 10010001 10011101
# Underflow: 01111000 10100010 10111011
# Underflow: 01110000 11000100 11110111
# Queden alpha, gamma i beta: 112 196 247
#
# u
# 0.6170212765957446 0.7872340425531914
# {'\x1b': 1, 'S': 3, 'e': 8, 't': 4, 'z': 3, ' ': 7, 'j': 3, 'u': 8, 'g': 2, 's': 3, 'd': 2, "'": 1, 'n': 1, 'a': 1}
# Determinen nova lletra: u
# Nous alpha, gamma i beta: 195 196 218
# En binari: 11000011 11000100 11011010
# Reescalat: 10000110 10001000 10110101
# Reescalat: 00001100 00010001 01101011
# Reescalat: 00011000 00100010 11010111
# Queden alpha, gamma i beta: 24 34 215
#
# S
# 0.020833333333333332 0.08333333333333333
# {'\x1b': 1, 'S': 3, 'e': 8, 't': 4, 'z': 3, ' ': 7, 'j': 3, 'u': 9, 'g': 2, 's': 3, 'd': 2, "'": 1, 'n': 1, 'a': 1}
# Determinen nova lletra: S
# Nous alpha, gamma i beta: 28 34 39
# En binari: 00011100 00100010 00100111
# Reescalat: 00111000 01000100 01001111
# Reescalat: 01110000 10001001 10011111
# Underflow: 01100000 10010011 10111111
# Underflow: 01000000 10100111 11111111
# Queden alpha, gamma i beta: 64 167 255
#
#
# 0.4081632653061224 0.5510204081632653
# {'\x1b': 1, 'S': 4, 'e': 8, 't': 4, 'z': 3, ' ': 7, 'j': 3, 'u': 9, 'g': 2, 's': 3, 'd': 2, "'": 1, 'n': 1, 'a': 1}
# Determinen nova lletra:
# Nous alpha, gamma i beta: 142 167 168
# En binari: 10001110 10100111 10101000
# Reescalat: 00011100 01001111 01010001
# Reescalat: 00111000 10011110 10100011
# Queden alpha, gamma i beta: 56 158 163
#
# '
# 0.9400000000000002 0.9600000000000002
# {'\x1b': 1, 'S': 4, 'e': 8, 't': 4, 'z': 3, ' ': 8, 'j': 3, 'u': 9, 'g': 2, 's': 3, 'd': 2, "'": 1, 'n': 1, 'a': 1}
# Determinen nova lletra: '
# Nous alpha, gamma i beta: 157 158 158
# En binari: 10011101 10011110 10011110
# Reescalat: 00111010 00111101 00111101
# Reescalat: 01110100 01111011 01111011
# Reescalat: 11101000 11110110 11110111
# Reescalat: 11010000 11101101 11101111
# Reescalat: 10100000 11011010 11011111
# Reescalat: 01000000 10110100 10111111
# Underflow: 00000000 11101000 11111111
# Queden alpha, gamma i beta: 0 232 255
# "Setze jutges d'un jutsausguzuS ej eSu e tedzeuuS '"
